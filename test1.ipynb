# %% [markdown]
# # 1. EDA dataset

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision.transforms as transforms

#Load Fashion MNIST dataset
transform = transforms.ToTensor()
trainset = torchvision.datasets.FashionMNIST(root='./data',train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# %%
trainset.classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#Class labels
class_labels = trainset.classes

#Basic statistics
num_train_samples = len(trainset)
num_test_samples = len(testset)
num_classes = len(class_labels)

print("Number of training samples:", num_train_samples)
print("Number of test samples:", num_test_samples)
print("Number of classes:", num_classes)

#Print image size
sample_image, _ = next(iter(trainset))
print("Image size:", sample_image.shape)
# Out:
# Number of training samples: 60000
# Number of test samples: 10000
# Number of classes: 10
# Image size: torch.Size([1, 28, 28])

# %% [markdown]
# ### Visualize

# %%
#Class distribution in training set
train_class_distribution = np.bincount(trainset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels, y=train_class_distribution)
plt.title("Class Distribution in Training Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
test_class_distribution = np.bincount(testset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels,y=test_class_distribution)
plt.title("Class Distribution in Test Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
#Display sample images from training set
plt.figure(figsize=(10,5))
for i in range(num_classes):
    plt.subplot(2, 5, i+1)
    img, label = trainset[i]
    img = np.transpose(img.numpy(), (1,2,0))
    plt.imshow(img)
    plt.title(class_labels[label])
    plt.axis('off')
plt.show()

# %% [markdown]
# # 2. Modeling

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Define model simple

# %%
class CustomNN(nn.Module):
    def __init__(self, input_size, hidden_layers, output_size, dropout_p, activation):
        super(CustomNN, self).__init__()
        self.layers = nn.ModuleList()
        
        #Input layer:
        self.layers.append(nn.Linear(input_size, hidden_layers[0]))
        self.layers.append(activation)
        self.layers.append(nn.Dropout(p=dropout_p))
        
        #Hidden layers
        for i in range(1, len(hidden_layers)):
            self.layers.append(nn.Linear(hidden_layers[i-1], hidden_layers[i]))
            self.layers.append(activation)
            self.layers.append(nn.Dropout(p=dropout_p))
            
        #Output layers
        self.layers.append(nn.Linear(hidden_layers[-1], output_size))
        
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %% [markdown]
# ### Testing model

# %%
#Testing model
input_size = 784
hidden_layer = [256, 128]
output_size = 10
dropout_p = 0.2
activation = nn.Tanh()

model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)
print(model)
# Out:
# CustomNN(
#   (layers): ModuleList(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): Tanh()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): Tanh()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # 3. Training model

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, ExponentialLR, CosineAnnealingLR
from sklearn.metrics import f1_score
from torch.utils.data import DataLoader

# %% [markdown]
# ### Configs model

# %% [markdown]
# # Batching data + convert data to tensor

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EPOCHS = 60
BATCH_SIZE = 128 #Can adjust

#Creat data loader
TRAINLOADER = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
TESTLOADER = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Define optimizer init model
#
# ##### Optimizer dictionary:
# ##### "SGD": optim.SGD(model.parameters(), lr=0.001)
# ##### "Momentum": optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# ##### "Adam": optim.Adam(model.parameters(), lr=0.001)
#
# ##### Learning rate schedulers dictionary
# ##### "Step Decay": StepLR(optimizer, step_size=30, gamma=0.5)
# ##### "Exponential Decay": ExponentialLR(optimizer, gamma=0.95)
# ##### "Cosine Annealing": CosineAnnealingLR(optimizer, T_max=5)

# %%
# Init Model
input_size = 28*28
hidden_layer = [256, 128, 64]
output_size = 10
dropout_p = 0.2
activation = nn.ReLU()
model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)

#Model to CUDA
model.to(DEVICE)

#Loss
criterion = nn.CrossEntropyLoss()

#Optimizer and Scheduler
optimizer = optim.Adam(model.parameters(), lr=0.001) #Choose the optimizer
# scheduler = CosineAnnealingLR(optimizer, T_max=5) # Choose the scheduler
scheduler = None

# %%
loss_train = []
loss_test = []
f1_train = []
f1_test = []

for epoch in range(EPOCHS):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    predictions_train = []
    true_labels_train = []
    for i, data in enumerate(TRAINLOADER, 0):
        inputs, labels = data
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()
        outputs =  model(inputs.view(-1, input_size))
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        predictions_train.extend(predicted.tolist())
        true_labels_train.extend(labels.tolist())
    if scheduler is not None:
        scheduler.step()  # Update learning rate with scheduler
    train_loss = running_loss / len(TRAINLOADER)
    train_f1 = f1_score(true_labels_train, predictions_train, average='weighted')

    loss_train.append(train_loss)
    f1_train.append(train_f1)

    # Evaluation on test set
    model.eval()  # Set the model to evaluation mode
    test_loss_val = 0.0
    predictions = []
    true_labels = []

    with torch.no_grad():
        for data in TESTLOADER:
            inputs, labels = data
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            outputs = model(inputs.view(-1, input_size))
            #outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss_val += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            predictions.extend(predicted.tolist())
            true_labels.extend(labels.tolist())

    test_loss_val /= len(TESTLOADER)
    test_f1_val = f1_score(true_labels, predictions, average='weighted')

    loss_test.append(test_loss_val)
    f1_test.append(test_f1_val)
    print(f'Epoch [{epoch + 1}/{EPOCHS}]  - Train Loss: {train_loss:.4f} - Train F1: {train_f1:.4f} - Test Loss: {test_loss_val:.4f} - Test F1: {test_f1_val:.4f}')

print('Finished Training')
# Out:
# Epoch [1/60]  - Train Loss: 0.6848 - Train F1: 0.7466 - Test Loss: 0.4728 - Test F1: 0.8288
# Epoch [2/60]  - Train Loss: 0.4372 - Train F1: 0.8424 - Test Loss: 0.4129 - Test F1: 0.8510
# Epoch [3/60]  - Train Loss: 0.3948 - Train F1: 0.8572 - Test Loss: 0.3889 - Test F1: 0.8608
# Epoch [4/60]  - Train Loss: 0.3649 - Train F1: 0.8677 - Test Loss: 0.3601 - Test F1: 0.8663
# Epoch [5/60]  - Train Loss: 0.3483 - Train F1: 0.8739 - Test Loss: 0.3576 - Test F1: 0.8694
# Epoch [6/60]  - Train Loss: 0.3335 - Train F1: 0.8790 - Test Loss: 0.3379 - Test F1: 0.8811
# Epoch [7/60]  - Train Loss: 0.3189 - Train F1: 0.8840 - Test Loss: 0.3364 - Test F1: 0.8799
# Epoch [8/60]  - Train Loss: 0.3097 - Train F1: 0.8870 - Test Loss: 0.3489 - Test F1: 0.8753
# Epoch [9/60]  - Train Loss: 0.2997 - Train F1: 0.8899 - Test Loss: 0.3350 - Test F1: 0.8780
# Epoch [10/60]  - Train Loss: 0.2971 - Train F1: 0.8914 - Test Loss: 0.3221 - Test F1: 0.8828
# Epoch [11/60]  - Train Loss: 0.2883 - Train F1: 0.8944 - Test Loss: 0.3338 - Test F1: 0.8795
# Epoch [12/60]  - Train Loss: 0.2806 - Train F1: 0.8960 - Test Loss: 0.3297 - Test F1: 0.8819
# Epoch [13/60]  - Train Loss: 0.2737 - Train F1: 0.8984 - Test Loss: 0.3309 - Test F1: 0.8803
# Epoch [14/60]  - Train Loss: 0.2709 - Train F1: 0.9001 - Test Loss: 0.3234 - Test F1: 0.8861
# Epoch [15/60]  - Train Loss: 0.2632 - Train F1: 0.9023 - Test Loss: 0.3177 - Test F1: 0.8826
# Epoch [16/60]  - Train Loss: 0.2612 - Train F1: 0.9029 - Test Loss: 0.3191 - Test F1: 0.8860
# Epoch [17/60]  - Train Loss: 0.2540 - Train F1: 0.9052 - Test Loss: 0.3095 - Test F1: 0.8859
# Epoch [18/60]  - Train Loss: 0.2514 - Train F1: 0.9074 - Test Loss: 0.3177 - Test F1: 0.8882
# Epoch [19/60]  - Train Loss: 0.2478 - Train F1: 0.9073 - Test Loss: 0.3123 - Test F1: 0.8903
# Epoch [20/60]  - Train Loss: 0.2432 - Train F1: 0.9095 - Test Loss: 0.3207 - Test F1: 0.8882
# Epoch [21/60]  - Train Loss: 0.2401 - Train F1: 0.9098 - Test Loss: 0.3219 - Test F1: 0.8844
# Epoch [22/60]  - Train Loss: 0.2368 - Train F1: 0.9113 - Test Loss: 0.3180 - Test F1: 0.8891
# Epoch [23/60]  - Train Loss: 0.2295 - Train F1: 0.9140 - Test Loss: 0.3318 - Test F1: 0.8905
# Epoch [24/60]  - Train Loss: 0.2293 - Train F1: 0.9137 - Test Loss: 0.3277 - Test F1: 0.8874
# Epoch [25/60]  - Train Loss: 0.2252 - Train F1: 0.9149 - Test Loss: 0.3224 - Test F1: 0.8930
# Epoch [26/60]  - Train Loss: 0.2217 - Train F1: 0.9170 - Test Loss: 0.3319 - Test F1: 0.8951
# Epoch [27/60]  - Train Loss: 0.2195 - Train F1: 0.9188 - Test Loss: 0.3131 - Test F1: 0.8950
# Epoch [28/60]  - Train Loss: 0.2195 - Train F1: 0.9178 - Test Loss: 0.3122 - Test F1: 0.8936
# Epoch [29/60]  - Train Loss: 0.2173 - Train F1: 0.9189 - Test Loss: 0.3107 - Test F1: 0.8946
# Epoch [30/60]  - Train Loss: 0.2120 - Train F1: 0.9199 - Test Loss: 0.3200 - Test F1: 0.8915
# Epoch [31/60]  - Train Loss: 0.2100 - Train F1: 0.9216 - Test Loss: 0.3253 - Test F1: 0.8944
# Epoch [32/60]  - Train Loss: 0.2077 - Train F1: 0.9221 - Test Loss: 0.3282 - Test F1: 0.8928
# Epoch [33/60]  - Train Loss: 0.2072 - Train F1: 0.9220 - Test Loss: 0.3150 - Test F1: 0.8944
# Epoch [34/60]  - Train Loss: 0.2037 - Train F1: 0.9235 - Test Loss: 0.3259 - Test F1: 0.8936
# Epoch [35/60]  - Train Loss: 0.2021 - Train F1: 0.9239 - Test Loss: 0.3405 - Test F1: 0.8902
# Epoch [36/60]  - Train Loss: 0.1971 - Train F1: 0.9254 - Test Loss: 0.3188 - Test F1: 0.8939
# Epoch [37/60]  - Train Loss: 0.1972 - Train F1: 0.9247 - Test Loss: 0.3222 - Test F1: 0.8926
# Epoch [38/60]  - Train Loss: 0.1961 - Train F1: 0.9259 - Test Loss: 0.3135 - Test F1: 0.8971
# Epoch [39/60]  - Train Loss: 0.1925 - Train F1: 0.9271 - Test Loss: 0.3283 - Test F1: 0.8915
# Epoch [40/60]  - Train Loss: 0.1908 - Train F1: 0.9272 - Test Loss: 0.3267 - Test F1: 0.8914
# Epoch [41/60]  - Train Loss: 0.1881 - Train F1: 0.9287 - Test Loss: 0.3451 - Test F1: 0.8950
# Epoch [42/60]  - Train Loss: 0.1926 - Train F1: 0.9278 - Test Loss: 0.3310 - Test F1: 0.8946
# Epoch [43/60]  - Train Loss: 0.1895 - Train F1: 0.9294 - Test Loss: 0.3252 - Test F1: 0.8937
# Epoch [44/60]  - Train Loss: 0.1821 - Train F1: 0.9308 - Test Loss: 0.3421 - Test F1: 0.8960
# Epoch [45/60]  - Train Loss: 0.1820 - Train F1: 0.9320 - Test Loss: 0.3340 - Test F1: 0.8981
# Epoch [46/60]  - Train Loss: 0.1819 - Train F1: 0.9313 - Test Loss: 0.3217 - Test F1: 0.8951
# Epoch [47/60]  - Train Loss: 0.1786 - Train F1: 0.9319 - Test Loss: 0.3252 - Test F1: 0.8950
# Epoch [48/60]  - Train Loss: 0.1781 - Train F1: 0.9325 - Test Loss: 0.3331 - Test F1: 0.8939
# Epoch [49/60]  - Train Loss: 0.1744 - Train F1: 0.9345 - Test Loss: 0.3502 - Test F1: 0.8973
# Epoch [50/60]  - Train Loss: 0.1727 - Train F1: 0.9359 - Test Loss: 0.3288 - Test F1: 0.8973
# Epoch [51/60]  - Train Loss: 0.1713 - Train F1: 0.9352 - Test Loss: 0.3406 - Test F1: 0.8958
# Epoch [52/60]  - Train Loss: 0.1700 - Train F1: 0.9360 - Test Loss: 0.3364 - Test F1: 0.8975
# Epoch [53/60]  - Train Loss: 0.1695 - Train F1: 0.9357 - Test Loss: 0.3341 - Test F1: 0.8966
# Epoch [54/60]  - Train Loss: 0.1722 - Train F1: 0.9359 - Test Loss: 0.3320 - Test F1: 0.8979
# Epoch [55/60]  - Train Loss: 0.1656 - Train F1: 0.9374 - Test Loss: 0.3469 - Test F1: 0.8947
# Epoch [56/60]  - Train Loss: 0.1659 - Train F1: 0.9370 - Test Loss: 0.3535 - Test F1: 0.8982
# Epoch [57/60]  - Train Loss: 0.1650 - Train F1: 0.9379 - Test Loss: 0.3335 - Test F1: 0.8990
# Epoch [58/60]  - Train Loss: 0.1620 - Train F1: 0.9387 - Test Loss: 0.3405 - Test F1: 0.8968
# Epoch [59/60]  - Train Loss: 0.1653 - Train F1: 0.9381 - Test Loss: 0.3659 - Test F1: 0.8922
# Epoch [60/60]  - Train Loss: 0.1592 - Train F1: 0.9406 - Test Loss: 0.3428 - Test F1: 0.8957
# Finished Training

# %%
#plotting the metrics
plt.figure(figsize=(12, 6))

plt.subplot(1,2,1)
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_test, label="Test Loss")
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_train, label="Train F1 Score")
plt.plot(f1_test, label="Test F1 Score")
plt.title("F1 Score over epochs")
plt.xlabel("Epochs")
plt.ylabel("F1 Score")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Evaluation model

# %%
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import seaborn as sns

# %%
model.eval()
all_predictions = []
all_true_labels = []

with torch.no_grad():
    for data in TESTLOADER:
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = model(inputs.view(-1, input_size))
        _, predicted = torch.max(outputs.data, 1)
        all_predictions.extend(predicted.cpu().tolist())
        all_true_labels.extend(labels.cpu().tolist())
        
    #Compute confusion matrix
    cm = confusion_matrix(all_true_labels, all_predictions)
    
    #Plot confusion matrix using Seaborn
    plt.figure(figsize=(10,7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel("Predictec labels")
    plt.ylabel("True labels")
    plt.title("Confusion Matrix")
    plt.show()

# %%
f1 = f1_score(all_true_labels, all_predictions, average="weighted")
print("Weighted F1 Score:", f1)
# Out:
# Weighted F1 Score: 0.8957108577723482

# %%
print(classification_report(all_true_labels, all_predictions, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.86      0.85      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.83      0.80      0.81      1000
#        Dress       0.87      0.92      0.90      1000
#         Coat       0.79      0.86      0.82      1000
#       Sandal       0.98      0.97      0.97      1000
#        Shirt       0.76      0.68      0.72      1000
#      Sneaker       0.95      0.97      0.96      1000
#          Bag       0.98      0.97      0.98      1000
#   Ankle boot       0.97      0.96      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
