# %% [markdown]
# # 1. EDA dataset

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision.transforms as transforms

#Load Fashion MNIST dataset
transform = transforms.ToTensor()
trainset = torchvision.datasets.FashionMNIST(root='./data',train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# %%
trainset.classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#Class labels
class_labels = trainset.classes

#Basic statistics
num_train_samples = len(trainset)
num_test_samples = len(testset)
num_classes = len(class_labels)

print("Number of training samples:", num_train_samples)
print("Number of test samples:", num_test_samples)
print("Number of classes:", num_classes)

#Print image size
sample_image, _ = next(iter(trainset))
print("Image size:", sample_image.shape)
# Out:
# Number of training samples: 60000
# Number of test samples: 10000
# Number of classes: 10
# Image size: torch.Size([1, 28, 28])

# %% [markdown]
# ### Visualize

# %%
#Class distribution in training set
train_class_distribution = np.bincount(trainset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels, y=train_class_distribution)
plt.title("Class Distribution in Training Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
test_class_distribution = np.bincount(testset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels,y=test_class_distribution)
plt.title("Class Distribution in Test Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
#Display sample images from training set
plt.figure(figsize=(10,5))
for i in range(num_classes):
    plt.subplot(2, 5, i+1)
    img, label = trainset[i]
    img = np.transpose(img.numpy(), (1,2,0))
    plt.imshow(img)
    plt.title(class_labels[label])
    plt.axis('off')
plt.show()

# %% [markdown]
# # 2. Modeling

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Define model simple

# %%
class CustomNN(nn.Module):
    def __init__(self, input_size, hidden_layers, output_size, dropout_p, activation):
        super(CustomNN, self).__init__()
        self.layers = nn.ModuleList()
        
        #Input layer:
        self.layers.append(nn.Linear(input_size, hidden_layers[0]))
        self.layers.append(activation)
        self.layers.append(nn.Dropout(p=dropout_p))
        
        #Hidden layers
        for i in range(1, len(hidden_layers)):
            self.layers.append(nn.Linear(hidden_layers[i-1], hidden_layers[i]))
            self.layers.append(activation)
            self.layers.append(nn.Dropout(p=dropout_p))
            
        #Output layers
        self.layers.append(nn.Linear(hidden_layers[-1], output_size))
        
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %% [markdown]
# ### Testing model

# %%
#Testing model
input_size = 784
hidden_layer = [256, 128]
output_size = 10
dropout_p = 0.2
activation = nn.Tanh()

model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)
print(model)
# Out:
# CustomNN(
#   (layers): ModuleList(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): Tanh()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): Tanh()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # 3. Training model

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, ExponentialLR, CosineAnnealingLR
from sklearn.metrics import f1_score
from torch.utils.data import DataLoader

# %% [markdown]
# ### Configs model

# %% [markdown]
# # Batching data + convert data to tensor

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EPOCHS = 40
BATCH_SIZE = 256 #Can adjust

#Creat data loader
TRAINLOADER = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
TESTLOADER = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Define optimizer init model
#
# ##### Optimizer dictionary:
# ##### "SGD": optim.SGD(model.parameters(), lr=0.001)
# ##### "Momentum": optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# ##### "Adam": optim.Adam(model.parameters(), lr=0.001)
#
# ##### Learning rate schedulers dictionary
# ##### "Step Decay": StepLR(optimizer, step_size=30, gamma=0.5)
# ##### "Exponential Decay": ExponentialLR(optimizer, gamma=0.95)
# ##### "Cosine Annealing": CosineAnnealingLR(optimizer, T_max=5)

# %%
# Init Model
input_size = 28*28
hidden_layer = [256, 128]
output_size = 10
dropout_p = 0.4
activation = nn.ReLU()
model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)

#Model to CUDA
model.to(DEVICE)

#Loss
criterion = nn.CrossEntropyLoss()

#Optimizer and Scheduler
optimizer = optim.Adam(model.parameters(), lr=0.005) #Choose the optimizer
# scheduler = CosineAnnealingLR(optimizer, T_max=5) # Choose the scheduler
scheduler = None

# %%
loss_train = []
loss_test = []
f1_train = []
f1_test = []

for epoch in range(EPOCHS):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    predictions_train = []
    true_labels_train = []
    for i, data in enumerate(TRAINLOADER, 0):
        inputs, labels = data
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()
        outputs =  model(inputs.view(-1, input_size))
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        predictions_train.extend(predicted.tolist())
        true_labels_train.extend(labels.tolist())
    if scheduler is not None:
        scheduler.step()  # Update learning rate with scheduler
    train_loss = running_loss / len(TRAINLOADER)
    train_f1 = f1_score(true_labels_train, predictions_train, average='weighted')

    loss_train.append(train_loss)
    f1_train.append(train_f1)

    # Evaluation on test set
    model.eval()  # Set the model to evaluation mode
    test_loss_val = 0.0
    predictions = []
    true_labels = []

    with torch.no_grad():
        for data in TESTLOADER:
            inputs, labels = data
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            outputs = model(inputs.view(-1, input_size))
            #outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss_val += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            predictions.extend(predicted.tolist())
            true_labels.extend(labels.tolist())

    test_loss_val /= len(TESTLOADER)
    test_f1_val = f1_score(true_labels, predictions, average='weighted')

    loss_test.append(test_loss_val)
    f1_test.append(test_f1_val)
    print(f'Epoch [{epoch + 1}/{EPOCHS}]  - Train Loss: {train_loss:.4f} - Train F1: {train_f1:.4f} - Test Loss: {test_loss_val:.4f} - Test F1: {test_f1_val:.4f}')

print('Finished Training')
# Out:
# Epoch [1/40]  - Train Loss: 0.6365 - Train F1: 0.7614 - Test Loss: 0.4496 - Test F1: 0.8364
# Epoch [2/40]  - Train Loss: 0.4854 - Train F1: 0.8228 - Test Loss: 0.4197 - Test F1: 0.8409
# Epoch [3/40]  - Train Loss: 0.4602 - Train F1: 0.8320 - Test Loss: 0.4237 - Test F1: 0.8383
# Epoch [4/40]  - Train Loss: 0.4460 - Train F1: 0.8385 - Test Loss: 0.3985 - Test F1: 0.8523
# Epoch [5/40]  - Train Loss: 0.4357 - Train F1: 0.8406 - Test Loss: 0.3928 - Test F1: 0.8537
# Epoch [6/40]  - Train Loss: 0.4310 - Train F1: 0.8436 - Test Loss: 0.3835 - Test F1: 0.8593
# Epoch [7/40]  - Train Loss: 0.4210 - Train F1: 0.8452 - Test Loss: 0.3815 - Test F1: 0.8577
# Epoch [8/40]  - Train Loss: 0.4180 - Train F1: 0.8476 - Test Loss: 0.3745 - Test F1: 0.8640
# Epoch [9/40]  - Train Loss: 0.4079 - Train F1: 0.8519 - Test Loss: 0.3729 - Test F1: 0.8635
# Epoch [10/40]  - Train Loss: 0.3997 - Train F1: 0.8523 - Test Loss: 0.3792 - Test F1: 0.8568
# Epoch [11/40]  - Train Loss: 0.3991 - Train F1: 0.8544 - Test Loss: 0.3633 - Test F1: 0.8631
# Epoch [12/40]  - Train Loss: 0.3931 - Train F1: 0.8567 - Test Loss: 0.3682 - Test F1: 0.8698
# Epoch [13/40]  - Train Loss: 0.3907 - Train F1: 0.8573 - Test Loss: 0.3609 - Test F1: 0.8643
# Epoch [14/40]  - Train Loss: 0.3865 - Train F1: 0.8598 - Test Loss: 0.3631 - Test F1: 0.8631
# Epoch [15/40]  - Train Loss: 0.3904 - Train F1: 0.8576 - Test Loss: 0.3556 - Test F1: 0.8679
# Epoch [16/40]  - Train Loss: 0.3816 - Train F1: 0.8606 - Test Loss: 0.3757 - Test F1: 0.8708
# Epoch [17/40]  - Train Loss: 0.3815 - Train F1: 0.8603 - Test Loss: 0.3669 - Test F1: 0.8637
# Epoch [18/40]  - Train Loss: 0.3792 - Train F1: 0.8614 - Test Loss: 0.3646 - Test F1: 0.8676
# Epoch [19/40]  - Train Loss: 0.3754 - Train F1: 0.8629 - Test Loss: 0.3655 - Test F1: 0.8568
# Epoch [20/40]  - Train Loss: 0.3750 - Train F1: 0.8623 - Test Loss: 0.3531 - Test F1: 0.8659
# Epoch [21/40]  - Train Loss: 0.3765 - Train F1: 0.8628 - Test Loss: 0.3455 - Test F1: 0.8743
# Epoch [22/40]  - Train Loss: 0.3748 - Train F1: 0.8637 - Test Loss: 0.3575 - Test F1: 0.8706
# Epoch [23/40]  - Train Loss: 0.3715 - Train F1: 0.8642 - Test Loss: 0.3683 - Test F1: 0.8644
# Epoch [24/40]  - Train Loss: 0.3748 - Train F1: 0.8642 - Test Loss: 0.3667 - Test F1: 0.8589
# Epoch [25/40]  - Train Loss: 0.3658 - Train F1: 0.8657 - Test Loss: 0.3548 - Test F1: 0.8659
# Epoch [26/40]  - Train Loss: 0.3643 - Train F1: 0.8668 - Test Loss: 0.3511 - Test F1: 0.8734
# Epoch [27/40]  - Train Loss: 0.3618 - Train F1: 0.8688 - Test Loss: 0.3519 - Test F1: 0.8686
# Epoch [28/40]  - Train Loss: 0.3680 - Train F1: 0.8664 - Test Loss: 0.3621 - Test F1: 0.8643
# Epoch [29/40]  - Train Loss: 0.3630 - Train F1: 0.8669 - Test Loss: 0.3480 - Test F1: 0.8705
# Epoch [30/40]  - Train Loss: 0.3601 - Train F1: 0.8680 - Test Loss: 0.3592 - Test F1: 0.8713
# Epoch [31/40]  - Train Loss: 0.3633 - Train F1: 0.8683 - Test Loss: 0.3595 - Test F1: 0.8698
# Epoch [32/40]  - Train Loss: 0.3552 - Train F1: 0.8701 - Test Loss: 0.3692 - Test F1: 0.8667
# Epoch [33/40]  - Train Loss: 0.3562 - Train F1: 0.8714 - Test Loss: 0.3496 - Test F1: 0.8787
# Epoch [34/40]  - Train Loss: 0.3538 - Train F1: 0.8724 - Test Loss: 0.3465 - Test F1: 0.8766
# Epoch [35/40]  - Train Loss: 0.3571 - Train F1: 0.8706 - Test Loss: 0.3733 - Test F1: 0.8697
# Epoch [36/40]  - Train Loss: 0.3569 - Train F1: 0.8698 - Test Loss: 0.3609 - Test F1: 0.8643
# Epoch [37/40]  - Train Loss: 0.3530 - Train F1: 0.8721 - Test Loss: 0.3608 - Test F1: 0.8638
# Epoch [38/40]  - Train Loss: 0.3540 - Train F1: 0.8723 - Test Loss: 0.3570 - Test F1: 0.8716
# Epoch [39/40]  - Train Loss: 0.3537 - Train F1: 0.8720 - Test Loss: 0.3562 - Test F1: 0.8712
# Epoch [40/40]  - Train Loss: 0.3560 - Train F1: 0.8717 - Test Loss: 0.3592 - Test F1: 0.8712
# Finished Training

# %%
#plotting the metrics
plt.figure(figsize=(12, 6))

plt.subplot(1,2,1)
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_test, label="Test Loss")
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_train, label="Train F1 Score")
plt.plot(f1_test, label="Test F1 Score")
plt.title("F1 Score over epochs")
plt.xlabel("Epochs")
plt.ylabel("F1 Score")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Evaluation model

# %%
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import seaborn as sns

# %%
model.eval()
all_predictions = []
all_true_labels = []

with torch.no_grad():
    for data in TESTLOADER:
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = model(inputs.view(-1, input_size))
        _, predicted = torch.max(outputs.data, 1)
        all_predictions.extend(predicted.cpu().tolist())
        all_true_labels.extend(labels.cpu().tolist())
        
    #Compute confusion matrix
    cm = confusion_matrix(all_true_labels, all_predictions)
    
    #Plot confusion matrix using Seaborn
    plt.figure(figsize=(10,7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel("Predictec labels")
    plt.ylabel("True labels")
    plt.title("Confusion Matrix")
    plt.show()

# %%
f1 = f1_score(all_true_labels, all_predictions, average="weighted")
print("Weighted F1 Score:", f1)
# Out:
# Weighted F1 Score: 0.8711765413868193

# %%
print(classification_report(all_true_labels, all_predictions, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.76      0.90      0.83      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.75      0.80      0.78      1000
#        Dress       0.86      0.89      0.88      1000
#         Coat       0.76      0.81      0.78      1000
#       Sandal       0.97      0.97      0.97      1000
#        Shirt       0.76      0.53      0.63      1000
#      Sneaker       0.92      0.97      0.94      1000
#          Bag       0.99      0.96      0.98      1000
#   Ankle boot       0.98      0.93      0.95      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
