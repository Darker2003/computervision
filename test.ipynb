# %% [markdown]
# # 1. EDA dataset

# %%
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision.transforms as transforms

#Load Fashion MNIST dataset
transform = transforms.ToTensor()
trainset = torchvision.datasets.FashionMNIST(root='./data',train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# %%
trainset.classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#Class labels
class_labels = trainset.classes

#Basic statistics
num_train_samples = len(trainset)
num_test_samples = len(testset)
num_classes = len(class_labels)

print("Number of training samples:", num_train_samples)
print("Number of test samples:", num_test_samples)
print("Number of classes:", num_classes)

#Print image size
sample_image, _ = next(iter(trainset))
print("Image size:", sample_image.shape)
# Out:
# Number of training samples: 60000
# Number of test samples: 10000
# Number of classes: 10
# Image size: torch.Size([1, 28, 28])

# %% [markdown]
# ### Visualize

# %%
#Class distribution in training set
train_class_distribution = np.bincount(trainset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels, y=train_class_distribution)
plt.title("Class Distribution in Training Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
test_class_distribution = np.bincount(testset.targets)
plt.figure(figsize=(10,6))
sns.barplot(x=class_labels,y=test_class_distribution)
plt.title("Class Distribution in Test Set")
plt.xlabel("Class")
plt.ylabel("Number of Samples")
plt.xticks(rotation=45)
plt.show()

# %%
#Display sample images from training set
plt.figure(figsize=(10,5))
for i in range(num_classes):
    plt.subplot(2, 5, i+1)
    img, label = trainset[i]
    img = np.transpose(img.numpy(), (1,2,0))
    plt.imshow(img)
    plt.title(class_labels[label])
    plt.axis('off')
plt.show()

# %% [markdown]
# # 2. Modeling

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Define model simple

# %%
class CustomNN(nn.Module):
    def __init__(self, input_size, hidden_layers, output_size, dropout_p, activation):
        super(CustomNN, self).__init__()
        self.layers = nn.ModuleList()
        
        #Input layer:
        self.layers.append(nn.Linear(input_size, hidden_layers[0]))
        self.layers.append(activation)
        self.layers.append(nn.Dropout(p=dropout_p))
        
        #Hidden layers
        for i in range(1, len(hidden_layers)):
            self.layers.append(nn.Linear(hidden_layers[i-1], hidden_layers[i]))
            self.layers.append(activation)
            self.layers.append(nn.Dropout(p=dropout_p))
            
        #Output layers
        self.layers.append(nn.Linear(hidden_layers[-1], output_size))
        
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %% [markdown]
# ### Testing model

# %%
#Testing model
input_size = 784
hidden_layer = [256, 128]
output_size = 10
dropout_p = 0.2
activation = nn.Tanh()

model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)
print(model)
# Out:
# CustomNN(
#   (layers): ModuleList(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): Tanh()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): Tanh()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # 3. Training model

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, ExponentialLR, CosineAnnealingLR
from sklearn.metrics import f1_score
from torch.utils.data import DataLoader

# %% [markdown]
# ### Configs model

# %% [markdown]
# # Batching data + convert data to tensor

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EPOCHS = 60
BATCH_SIZE = 256 #Can adjust

#Creat data loader
TRAINLOADER = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
TESTLOADER = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Define optimizer init model
#
# ##### Optimizer dictionary:
# ##### "SGD": optim.SGD(model.parameters(), lr=0.001)
# ##### "Momentum": optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# ##### "Adam": optim.Adam(model.parameters(), lr=0.001)
#
# ##### Learning rate schedulers dictionary
# ##### "Step Decay": StepLR(optimizer, step_size=30, gamma=0.5)
# ##### "Exponential Decay": ExponentialLR(optimizer, gamma=0.95)
# ##### "Cosine Annealing": CosineAnnealingLR(optimizer, T_max=5)

# %%
# Init Model
input_size = 28*28
hidden_layer = [256, 128, 64]
output_size = 10
dropout_p = 0.2
activation = nn.ReLU()
model = CustomNN(input_size, hidden_layer, output_size, dropout_p, activation)

#Model to CUDA
model.to(DEVICE)

#Loss
criterion = nn.CrossEntropyLoss()

#Optimizer and Scheduler
optimizer = optim.Adam(model.parameters(), lr=0.001) #Choose the optimizer
# scheduler = CosineAnnealingLR(optimizer, T_max=5) # Choose the scheduler
scheduler = StepLR(optimizer, step_size=30, gamma=0.5)

# %%
loss_train = []
loss_test = []
f1_train = []
f1_test = []

for epoch in range(EPOCHS):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    predictions_train = []
    true_labels_train = []
    for i, data in enumerate(TRAINLOADER, 0):
        inputs, labels = data
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()
        outputs =  model(inputs.view(-1, input_size))
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        predictions_train.extend(predicted.tolist())
        true_labels_train.extend(labels.tolist())
    if scheduler is not None:
        scheduler.step()  # Update learning rate with scheduler
    train_loss = running_loss / len(TRAINLOADER)
    train_f1 = f1_score(true_labels_train, predictions_train, average='weighted')

    loss_train.append(train_loss)
    f1_train.append(train_f1)

    # Evaluation on test set
    model.eval()  # Set the model to evaluation mode
    test_loss_val = 0.0
    predictions = []
    true_labels = []

    with torch.no_grad():
        for data in TESTLOADER:
            inputs, labels = data
            inputs = inputs.to(DEVICE)
            labels = labels.to(DEVICE)
            outputs = model(inputs.view(-1, input_size))
            #outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss_val += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            predictions.extend(predicted.tolist())
            true_labels.extend(labels.tolist())

    test_loss_val /= len(TESTLOADER)
    test_f1_val = f1_score(true_labels, predictions, average='weighted')

    loss_test.append(test_loss_val)
    f1_test.append(test_f1_val)
    print(f'Epoch [{epoch + 1}/{EPOCHS}]  - Train Loss: {train_loss:.4f} - Train F1: {train_f1:.4f} - Test Loss: {test_loss_val:.4f} - Test F1: {test_f1_val:.4f}')

print('Finished Training')
# Out:
# Epoch [1/60]  - Train Loss: 0.7944 - Train F1: 0.7037 - Test Loss: 0.4795 - Test F1: 0.8240
# Epoch [2/60]  - Train Loss: 0.4639 - Train F1: 0.8370 - Test Loss: 0.4176 - Test F1: 0.8475
# Epoch [3/60]  - Train Loss: 0.4097 - Train F1: 0.8546 - Test Loss: 0.4072 - Test F1: 0.8477
# Epoch [4/60]  - Train Loss: 0.3781 - Train F1: 0.8643 - Test Loss: 0.3815 - Test F1: 0.8601
# Epoch [5/60]  - Train Loss: 0.3540 - Train F1: 0.8732 - Test Loss: 0.3582 - Test F1: 0.8682
# Epoch [6/60]  - Train Loss: 0.3384 - Train F1: 0.8772 - Test Loss: 0.3523 - Test F1: 0.8683
# Epoch [7/60]  - Train Loss: 0.3283 - Train F1: 0.8810 - Test Loss: 0.3423 - Test F1: 0.8733
# Epoch [8/60]  - Train Loss: 0.3177 - Train F1: 0.8843 - Test Loss: 0.3360 - Test F1: 0.8789
# Epoch [9/60]  - Train Loss: 0.3075 - Train F1: 0.8882 - Test Loss: 0.3368 - Test F1: 0.8757
# Epoch [10/60]  - Train Loss: 0.2963 - Train F1: 0.8920 - Test Loss: 0.3399 - Test F1: 0.8752
# Epoch [11/60]  - Train Loss: 0.2921 - Train F1: 0.8939 - Test Loss: 0.3261 - Test F1: 0.8845
# Epoch [12/60]  - Train Loss: 0.2854 - Train F1: 0.8954 - Test Loss: 0.3227 - Test F1: 0.8838
# Epoch [13/60]  - Train Loss: 0.2758 - Train F1: 0.8983 - Test Loss: 0.3283 - Test F1: 0.8799
# Epoch [14/60]  - Train Loss: 0.2742 - Train F1: 0.8981 - Test Loss: 0.3158 - Test F1: 0.8831
# Epoch [15/60]  - Train Loss: 0.2658 - Train F1: 0.9011 - Test Loss: 0.3295 - Test F1: 0.8809
# Epoch [16/60]  - Train Loss: 0.2647 - Train F1: 0.9027 - Test Loss: 0.3123 - Test F1: 0.8871
# Epoch [17/60]  - Train Loss: 0.2582 - Train F1: 0.9053 - Test Loss: 0.3082 - Test F1: 0.8856
# Epoch [18/60]  - Train Loss: 0.2525 - Train F1: 0.9062 - Test Loss: 0.3200 - Test F1: 0.8866
# Epoch [19/60]  - Train Loss: 0.2497 - Train F1: 0.9058 - Test Loss: 0.3162 - Test F1: 0.8884
# Epoch [20/60]  - Train Loss: 0.2451 - Train F1: 0.9098 - Test Loss: 0.3139 - Test F1: 0.8869
# Epoch [21/60]  - Train Loss: 0.2377 - Train F1: 0.9116 - Test Loss: 0.3203 - Test F1: 0.8908
# Epoch [22/60]  - Train Loss: 0.2368 - Train F1: 0.9118 - Test Loss: 0.3101 - Test F1: 0.8919
# Epoch [23/60]  - Train Loss: 0.2305 - Train F1: 0.9144 - Test Loss: 0.3195 - Test F1: 0.8863
# Epoch [24/60]  - Train Loss: 0.2287 - Train F1: 0.9143 - Test Loss: 0.3016 - Test F1: 0.8889
# Epoch [25/60]  - Train Loss: 0.2279 - Train F1: 0.9150 - Test Loss: 0.3068 - Test F1: 0.8928
# Epoch [26/60]  - Train Loss: 0.2244 - Train F1: 0.9166 - Test Loss: 0.3100 - Test F1: 0.8906
# Epoch [27/60]  - Train Loss: 0.2202 - Train F1: 0.9182 - Test Loss: 0.3087 - Test F1: 0.8918
# Epoch [28/60]  - Train Loss: 0.2149 - Train F1: 0.9187 - Test Loss: 0.3079 - Test F1: 0.8955
# Epoch [29/60]  - Train Loss: 0.2123 - Train F1: 0.9194 - Test Loss: 0.3035 - Test F1: 0.8942
# Epoch [30/60]  - Train Loss: 0.2114 - Train F1: 0.9207 - Test Loss: 0.3063 - Test F1: 0.8939
# Epoch [31/60]  - Train Loss: 0.1924 - Train F1: 0.9280 - Test Loss: 0.3017 - Test F1: 0.8989
# Epoch [32/60]  - Train Loss: 0.1826 - Train F1: 0.9297 - Test Loss: 0.3135 - Test F1: 0.8986
# Epoch [33/60]  - Train Loss: 0.1823 - Train F1: 0.9312 - Test Loss: 0.3093 - Test F1: 0.8982
# Epoch [34/60]  - Train Loss: 0.1781 - Train F1: 0.9320 - Test Loss: 0.3179 - Test F1: 0.8979
# Epoch [35/60]  - Train Loss: 0.1769 - Train F1: 0.9335 - Test Loss: 0.3203 - Test F1: 0.8973
# Epoch [36/60]  - Train Loss: 0.1712 - Train F1: 0.9353 - Test Loss: 0.3105 - Test F1: 0.9011
# Epoch [37/60]  - Train Loss: 0.1708 - Train F1: 0.9356 - Test Loss: 0.3110 - Test F1: 0.8986
# Epoch [38/60]  - Train Loss: 0.1717 - Train F1: 0.9345 - Test Loss: 0.3105 - Test F1: 0.8963
# Epoch [39/60]  - Train Loss: 0.1652 - Train F1: 0.9377 - Test Loss: 0.3116 - Test F1: 0.9005
# Epoch [40/60]  - Train Loss: 0.1663 - Train F1: 0.9363 - Test Loss: 0.3298 - Test F1: 0.8969
# Epoch [41/60]  - Train Loss: 0.1631 - Train F1: 0.9396 - Test Loss: 0.3126 - Test F1: 0.8980
# Epoch [42/60]  - Train Loss: 0.1644 - Train F1: 0.9374 - Test Loss: 0.3123 - Test F1: 0.9030
# Epoch [43/60]  - Train Loss: 0.1599 - Train F1: 0.9395 - Test Loss: 0.3392 - Test F1: 0.8971
# Epoch [44/60]  - Train Loss: 0.1591 - Train F1: 0.9395 - Test Loss: 0.3234 - Test F1: 0.8973
# Epoch [45/60]  - Train Loss: 0.1567 - Train F1: 0.9402 - Test Loss: 0.3256 - Test F1: 0.8965
# Epoch [46/60]  - Train Loss: 0.1553 - Train F1: 0.9402 - Test Loss: 0.3231 - Test F1: 0.9004
# Epoch [47/60]  - Train Loss: 0.1550 - Train F1: 0.9404 - Test Loss: 0.3267 - Test F1: 0.8976
# Epoch [48/60]  - Train Loss: 0.1539 - Train F1: 0.9406 - Test Loss: 0.3260 - Test F1: 0.9005
# Epoch [49/60]  - Train Loss: 0.1519 - Train F1: 0.9427 - Test Loss: 0.3376 - Test F1: 0.8981
# Epoch [50/60]  - Train Loss: 0.1499 - Train F1: 0.9435 - Test Loss: 0.3321 - Test F1: 0.9013
# Epoch [51/60]  - Train Loss: 0.1482 - Train F1: 0.9439 - Test Loss: 0.3491 - Test F1: 0.8979
# Epoch [52/60]  - Train Loss: 0.1457 - Train F1: 0.9444 - Test Loss: 0.3256 - Test F1: 0.9016
# Epoch [53/60]  - Train Loss: 0.1451 - Train F1: 0.9441 - Test Loss: 0.3356 - Test F1: 0.9005
# Epoch [54/60]  - Train Loss: 0.1434 - Train F1: 0.9452 - Test Loss: 0.3221 - Test F1: 0.8994
# Epoch [55/60]  - Train Loss: 0.1436 - Train F1: 0.9460 - Test Loss: 0.3438 - Test F1: 0.8999
# Epoch [56/60]  - Train Loss: 0.1384 - Train F1: 0.9469 - Test Loss: 0.3268 - Test F1: 0.9018
# Epoch [57/60]  - Train Loss: 0.1395 - Train F1: 0.9477 - Test Loss: 0.3323 - Test F1: 0.8975
# Epoch [58/60]  - Train Loss: 0.1381 - Train F1: 0.9469 - Test Loss: 0.3435 - Test F1: 0.9017
# Epoch [59/60]  - Train Loss: 0.1344 - Train F1: 0.9493 - Test Loss: 0.3464 - Test F1: 0.8998
# Epoch [60/60]  - Train Loss: 0.1342 - Train F1: 0.9486 - Test Loss: 0.3444 - Test F1: 0.9006
# Finished Training

# %%
#plotting the metrics
plt.figure(figsize=(12, 6))

plt.subplot(1,2,1)
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_test, label="Test Loss")
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_train, label="Train F1 Score")
plt.plot(f1_test, label="Test F1 Score")
plt.title("F1 Score over epochs")
plt.xlabel("Epochs")
plt.ylabel("F1 Score")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Evaluation model

# %%
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import seaborn as sns

# %%
model.eval()
all_predictions = []
all_true_labels = []

with torch.no_grad():
    for data in TESTLOADER:
        inputs, labels = data
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        outputs = model(inputs.view(-1, input_size))
        _, predicted = torch.max(outputs.data, 1)
        all_predictions.extend(predicted.cpu().tolist())
        all_true_labels.extend(labels.cpu().tolist())
        
    #Compute confusion matrix
    cm = confusion_matrix(all_true_labels, all_predictions)
    
    #Plot confusion matrix using Seaborn
    plt.figure(figsize=(10,7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel("Predictec labels")
    plt.ylabel("True labels")
    plt.title("Confusion Matrix")
    plt.show()

# %%
f1 = f1_score(all_true_labels, all_predictions, average="weighted")
print("Weighted F1 Score:", f1)
# Out:
# Weighted F1 Score: 0.9006437055790497

# %%
print(classification_report(all_true_labels, all_predictions, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.86      0.85      0.86      1000
#      Trouser       0.99      0.98      0.98      1000
#     Pullover       0.83      0.81      0.82      1000
#        Dress       0.91      0.91      0.91      1000
#         Coat       0.83      0.83      0.83      1000
#       Sandal       0.97      0.98      0.97      1000
#        Shirt       0.72      0.75      0.74      1000
#      Sneaker       0.95      0.96      0.95      1000
#          Bag       0.97      0.98      0.98      1000
#   Ankle boot       0.97      0.96      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
