# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16026, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 16026 (delta 33), reused 41 (delta 25), pack-reused 15967
# Receiving objects: 100% (16026/16026), 14.61 MiB | 17.33 MiB/s, done.
# Resolving deltas: 100% (10999/10999), done.

# %%
PATH_YOLO = "/kaggle/working/yolov5"
PATH_MODEL = "/kaggle/input/yolov5-model/best.pt"

# %%
import torch
from glob import glob 
model = torch.hub.load(PATH_YOLO, 'custom', path=PATH_MODEL, source='local')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 24.8 MB/s eta 0:00:00
# ...
# YOLOv5 🚀 v7.0-230-g53efd07 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
# Inference
img = '/kaggle/input/samples/sample/aguanambi-1000_png_jpg.rf.7179a0df58ad6448028bc5bc21dca41e.jpg'
results = model([img])

predicts = results.pandas().xyxy[0]
predicts
# Out:
#           xmin        ymin        xmax        ymax  confidence  class  \
# 0   476.439026  146.067795  517.517273  200.437607    0.895045      2
# 1   306.385040  523.474548  329.671783  632.442810    0.871377      0
# 2   356.568604  108.666397  381.421204  150.326309    0.862320      2
# 3   393.395203  107.373100  419.579468  152.979752    0.816182      2
# 4   383.766907   66.798874  404.376648  100.093536    0.815193      2
# 5   372.222565   87.262566  392.665924  123.115059    0.809706      2
# 6   401.844055  150.943802  414.338440  200.164841    0.780150      3
# 7   400.486694   39.047142  418.302002   62.750206    0.767700      2
# 8   511.746826   50.525894  525.953979   74.312805    0.758917      2
# 9   392.544006   53.171246  410.243225   79.933060    0.730799      2
# 10  404.814728   23.795963  422.697845   46.919758    0.706456      2
# 11  332.467957  503.072571  353.985962  628.274841    0.698112      0
# ...

# %%
results.show()  # or .show(), .save(), .crop(), .pandas(), etc
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
